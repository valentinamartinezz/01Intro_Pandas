# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.0

# %%
#Cargar los datos a la memoria RAM.
spotify=pd.read_csv("spotify-2023.csv",encoding="latin-1")
#Creamos un DF llamado spotify.

# %%
#Visualizar DF.
spotify.head(10)
#muestra los primeros registros.
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
# 8                             fukumean                       Gunna
# 9                      La Bebe - Remix       Peso Pluma, Yng Lvcas
#
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# ...

# %%
#muestra los ultimos 10 registros
spotify.tail(10)
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 943         Privileged Rappers    Drake, 21 Savage             2
# 944              The Astronaut                 Jin             1
# 945            BackOutsideBoyz               Drake             1
# 946                 Broke Boys    Drake, 21 Savage             2
# 947              The Great War        Taylor Swift             1
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 943           2022              11             4                  1007
# 944           2022              10            28                   481
# ...

# %%
#muestra 5 registros aleatorios 
spotify.sample(5)
# Out:
#                          track_name            artist(s)_name  artist_count  \
# 496  Jingle Bells - Remastered 1999             Frank Sinatra             1
# 416                           Blind                       SZA             1
# 182                           Creep                 Radiohead             1
# 64                          Hey Mor               Ozuna, Feid             2
# 772    Cooped Up (with Roddy Ricch)  Post Malone, Roddy Ricch             2
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 496           1957               1             1                  4326
# 416           2022              12             9                  1484
# 182           1992               9            21                 36724
# 64            2022              10             6                  4637
# 772           2022               5            12                  2942
#
#      in_spotify_charts     streams  in_apple_playlists  ...  bpm  key   mode  \
# ...

# %%
#visualizar caracteristicas generales de DF
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
spotify.shape
# Out:
# (953, 24)

# %%
spotify.index
# Out:
# RangeIndex(start=0, stop=953, step=1)

# %%
spotify.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %%
spotify.dtypes[5:9]
# Out:
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# dtype: object

# %%
spotify.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
spotify[spotify['released_year'] == 1930]
# Out:
#           track_name           artist(s)_name  artist_count  released_year  \
# 439  Agudo Mï¿½ï¿½gi  Styrx, utku INC, Thezth             3           1930
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 439               1             1                   323                  0
#
#       streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 439  90598517                   4  ...  130  F#  Minor             65
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 439         49       80             22                   4           7
#
#      speechiness_%
# 439              5
#
# [1 rows x 24 columns]

# %%
#visualizacion de una columna.
spotify['artist(s)_name']
# Out:
# 0        Latto, Jung Kook
# 1             Myke Towers
# 2          Olivia Rodrigo
# 3            Taylor Swift
# 4               Bad Bunny
#               ...
# 948          Selena Gomez
# 949          Taylor Swift
# 950    Feid, Paulo Londra
# 951    Feid, Sech, Jhayco
# 952             Burna Boy
# Name: artist(s)_name, Length: 953, dtype: object

# %%
#visualizacion de varias columnas.
spotify[['artist(s)_name','streams','mode']]
# Out:
#          artist(s)_name    streams   mode
# 0      Latto, Jung Kook  141381703  Major
# 1           Myke Towers  133716286  Major
# 2        Olivia Rodrigo  140003974  Major
# 3          Taylor Swift  800840817  Major
# 4             Bad Bunny  303236322  Minor
# ..                  ...        ...    ...
# 948        Selena Gomez   91473363  Major
# 949        Taylor Swift  121871870  Major
# 950  Feid, Paulo Londra   73513683  Major
# 951  Feid, Sech, Jhayco  133895612  Major
# 952           Burna Boy   96007391  Minor
#
# [953 rows x 3 columns]

# %%
#filtros
spotify[spotify['released_year']<=2000]
# Out:
#                                             track_name  \
# 65                                              Yellow
# 80                                             Riptide
# 114                  Everybody Wants To Rule The World
# 166            Every Breath You Take - Remastered 2003
# 182                                              Creep
# 195                       Have You Ever Seen The Rain?
# 199                                         Take On Me
# 250                                The Real Slim Shady
# 265  Cupid ï¿½ï¿½ï¿½ Twin Ver. (FIFTY FIFTY) ï¿½ï¿½...
# 320                                 Gangsta's Paradise
# 358                                         In The End
# 424             Running Up That Hill (A Deal With God)
# 425                                           Dream On
# 439                                    Agudo Mï¿½ï¿½gi
# 441                    All I Want for Christmas Is You
# 442                                     Last Christmas
# ...

# %%
#filtrar entre 2 valores
spotify[(spotify['released_year']<=2005)&(spotify['released_year']<=2009)]
# Out:
#                             track_name   artist(s)_name  artist_count  \
# 65                              Yellow    Chris Molitor             1
# 80                             Riptide        Vance Joy             1
# 103                        Mockingbird           Eminem             1
# 114  Everybody Wants To Rule The World  Tears For Fears             1
# 143                         Without Me           Eminem             1
# ..                                 ...              ...           ...
# 862     Master of Puppets (Remastered)        Metallica             1
# 871                Sweet Child O' Mine    Guns N' Roses             1
# 910                      The Scientist         Coldplay             1
# 911                             Sparks         Coldplay             1
# 922                           Miss You        Southstar             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# ...

# %%
#lista de canciones donde aparece ese artista 
spotify[spotify['artist(s)_name']== 'Jung Kook']
# Out:
#                          track_name artist(s)_name  artist_count  \
# 94                   Still With You      Jung Kook             1
# 650  Stay Alive (Prod. SUGA of BTS)      Jung Kook             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 94            2020               6             5                    31
# 650           2022               2            11                   590
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 94                  39   38411956                   2  ...   88  C#  Minor
# 650                  5  246376690                   4  ...  130   D  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 94              53         34       47              9                   0
# 650             51         50       76             30                   0
#
#      liveness_%  speechiness_%
# 94           83              4
# 650          10              7
#
# ...

# %%
#lista de artistas
spotify['artist(s)_name'].unique()
# Out:
# array(['Latto, Jung Kook', 'Myke Towers', 'Olivia Rodrigo',
#        'Taylor Swift', 'Bad Bunny', 'Dave, Central Cee',
#        'Eslabon Armado, Peso Pluma', 'Quevedo', 'Gunna',
#        'Peso Pluma, Yng Lvcas', 'Bad Bunny, Grupo Frontera', 'NewJeans',
#        'Miley Cyrus', 'David Kushner', 'Harry Styles', 'SZA',
#        'Fifty Fifty', 'Billie Eilish', 'Feid, Young Miko', 'Jimin',
#        'Gabito Ballesteros, Junior H, Peso Pluma', 'Arctic Monkeys',
#        'Bizarrap, Peso Pluma', 'The Weeknd, Madonna, Playboi Carti',
#        'Fuerza Regida', 'Rï¿½ï¿½ma, Selena G', 'Tainy, Bad Bunny',
#        'Morgan Wallen', 'Dua Lipa', 'Troye Sivan',
#        'Peso Pluma, Grupo Frontera',
#        'The Weeknd, 21 Savage, Metro Boomin', 'Karol G, Shakira',
#        'Big One, Duki, Lit Killah, Maria Becerra, FMK, Rusherking, Emilia, Tiago pzk',
#        'Yahritza Y Su Esencia, Grupo Frontera', 'Junior H, Peso Pluma',
#        'Post Malone, Swae Lee', 'Bebe Rexha, David Guetta',
# ...

# %%
spotify[(spotify['artist(s)_name']== 'Jung Kook') | (spotify['artist(s)_name']== 'Eminem') | (spotify['artist(s)_name']== 'Post Malone') | (spotify['artist(s)_name']== 'Billie Eilish') | (spotify['artist(s)_name']== 'Jin') |(spotify['artist(s)_name']== 'Jimin')|(spotify['artist(s)_name']== 'BTS')|(spotify['artist(s)_name']== 'OneRepublic')|(spotify['artist(s)_name']== 'Drake')]
# Out:
#                                             track_name artist(s)_name  \
# 17   What Was I Made For? [From The Motion Picture ...  Billie Eilish
# 19                                          Like Crazy          Jimin
# 46                                     I Ain't Worried    OneRepublic
# 68                                           Overdrive    Post Malone
# 94                                      Still With You      Jung Kook
# 99                                            Take Two            BTS
# 102                                           Chemical    Post Malone
# 103                                        Mockingbird         Eminem
# 143                                         Without Me         Eminem
# 157                                     Counting Stars    OneRepublic
# 187                                            Circles    Post Malone
# 235                                    Search & Rescue          Drake
# ...

# %%
mi_playlist = spotify [(spotify['artist(s)_name']=='Dua Lipa')|(spotify['artist(s)_name']== 'Jung Kook')|(spotify['artist(s)_name']== 'Eminem')|(spotify['artist(s)_name']== 'Post Malone')|(spotify['artist(s)_name']== 'Billie Eilish')|(spotify['artist(s)_name']== 'Jin')|(spotify['artist(s)_name']== 'Jimin')|(spotify['artist(s)_name']== 'BTS')|(spotify['artist(s)_name']== 'OneRepiblic')|(spotify['artist(s)_name']== 'Drake')]

# %%
mi_playlist.to_csv
# Out:
# <bound method NDFrame.to_csv of                                             track_name artist(s)_name  \
# 17   What Was I Made For? [From The Motion Picture ...  Billie Eilish
# 19                                          Like Crazy          Jimin
# 29             Dance The Night (From Barbie The Album)       Dua Lipa
# 68                                           Overdrive    Post Malone
# 94                                      Still With You      Jung Kook
# 99                                            Take Two            BTS
# 102                                           Chemical    Post Malone
# 103                                        Mockingbird         Eminem
# 143                                         Without Me         Eminem
# 187                                            Circles    Post Malone
# 235                                    Search & Rescue          Drake
# 250                                The Real Slim Shady         Eminem
# ...

# %% [markdown]
# # tarea
# ### En Visual Studio Code (VS Code), ETL se refiere a las operaciones de Extracción, Transformación y Carga de datos. Estas son actividades comunes en el desarrollo de software para la manipulación y análisis de datos, donde se extraen datos de una o varias fuentes, se transforman según las necesidades del usuario y luego se cargan en un destino final, como una base de datos o un archivo. VS Code ofrece diversas herramientas y extensiones que pueden ayudar en el desarrollo de procesos ETL, facilitando la escritura de código, la depuración y la visualización de los datos.
